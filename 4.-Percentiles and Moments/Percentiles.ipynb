# %% [markdown]
# # Percentiles

# %%
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)
plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.007480006593668187

# %%
np.percentile(vals, 90)
# Out:
# 0.6456041335162238

# %%
np.percentile(vals, 20)
# Out:
# -0.4256266583016586

# %%
np.percentile(vals, 100)
# Out:
# 1.8162363727341748

# %% [markdown]
# ## Activity
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %%
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 100)
plt.hist(vals, 10)
plt.show()

# %%
np.percentile(vals, 0)
# Out:
# -1.0067031084055358

# %%
np.percentile(vals, 20)
# Out:
# -0.3335488852068953

# %%
np.percentile(vals, 50)
# Out:
# 0.02019090817409192

# %%
np.percentile(vals, 99)
# Out:
# 1.0485424846658693
