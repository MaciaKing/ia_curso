# %% [markdown]
# # Train / Test

# %% [markdown]
# We'll start by creating some data set that we want to build a model for (in this case a polynomial regression):

# %%
# %matplotlib inline
import numpy as np
from pylab import *

np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# Now we'll split the data in two - 80% of it will be used for "training" our model, and the other 20% for testing it. This way we can avoid overfitting.

# %%
trainX = pageSpeeds[:80]
testX = pageSpeeds[80:]

trainY = purchaseAmount[:80]
testY = purchaseAmount[80:]

# %% [markdown]
# Here's our training dataset:

# %%
scatter(trainX, trainY)

# %% [markdown]
# And our test dataset:

# %%
scatter(testX, testY)

# %% [markdown]
# Now we'll try to fit an 8th-degree polynomial to this data (which is almost certainly overfitting, given what we know about how it was generated!)

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %% [markdown]
# Let's plot our polynomial against the training data:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# And against our test data:

# %%
testx = np.array(testX)
testy = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Doesn't look that bad when you just eyeball it, but the r-squared score on the test data is kind of horrible! This tells us that our model isn't all that great...

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)
# Out:
# 0.3001816861112493

# %% [markdown]
# ...even though it fits the training data better:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.6427069514692978

# %% [markdown]
# If you're working with a Pandas DataFrame (using tabular, labeled data,) scikit-learn has built-in train_test_split functions to make this easy to do.
#
# Later we'll talk about even more robust forms of train/test, like K-fold cross-validation - where we try out multiple different splits of the data, to make sure we didn't just get lucky with where we split it.

# %% [markdown]
# ## Activity

# %% [markdown]
# Try measuring the error on the test data using different degree polynomial fits. What degree works best?

# %%
p3 = np.poly1d(np.polyfit(x, y, 3))

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

xp = np.linspace(0, 7, 100)
axs[0].set_xlim([0, 7])
axs[0].set_ylim([0, 200])
axs[0].scatter(x, y)
axs[0].plot(xp, p3(xp), c='r')
axs[0].set_title("Train examples")

# Segundo gráfico - Test examples
axs[1].set_xlim([0, 7])
axs[1].set_ylim([0, 200])
axs[1].scatter(testx, testy)
axs[1].plot(xp, p3(xp), c='r')
axs[1].set_title("Test examples")

r2_test = r2_score(testy, p3(testx))
r2_train = r2_score(np.array(trainY), p3(np.array(trainX)))

print("r2 Train =", r2_train, "\nr2 Test =", r2_test)
# Out:
# r2 Train = 0.4295783201206693
# r2 Test = 0.2727431147520031

# %%
p5 = np.poly1d(np.polyfit(x, y, 5))

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

xp = np.linspace(0, 7, 100)
axs[0].set_xlim([0, 7])
axs[0].set_ylim([0, 200])
axs[0].scatter(x, y)
axs[0].plot(xp, p5(xp), c='r')
axs[0].set_title("Train examples")

# Segundo gráfico - Test examples
axs[1].set_xlim([0, 7])
axs[1].set_ylim([0, 200])
axs[1].scatter(testx, testy)
axs[1].plot(xp, p5(xp), c='r')
axs[1].set_title("Test examples")

r2_test = r2_score(testy, p5(testx))
r2_train = r2_score(np.array(trainY), p5(np.array(trainX)))

print("r2 Train =", r2_train, "\nr2 Test =", r2_test)
# Out:
# r2 Train = 0.5544872536567729
# r2 Test = 0.5040723897194141

# %%
p6 = np.poly1d(np.polyfit(x, y, 6))

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

xp = np.linspace(0, 7, 100)
axs[0].set_xlim([0, 7])
axs[0].set_ylim([0, 200])
axs[0].scatter(x, y)
axs[0].plot(xp, p5(xp), c='r')
axs[0].set_title("Train examples")

# Segundo gráfico - Test examples
axs[1].set_xlim([0, 7])
axs[1].set_ylim([0, 200])
axs[1].scatter(testx, testy)
axs[1].plot(xp, p5(xp), c='r')
axs[1].set_title("Test examples")

r2_test = r2_score(testy, p6(testx))
r2_train = r2_score(np.array(trainY), p6(np.array(trainX)))

print("r2 Train =", r2_train, "\nr2 Test =", r2_test)
# Out:
# r2 Train = 0.6025441707110558
# r2 Test = 0.6050119470355383

# %% [markdown]
# The best-fitting result seems to be a 6th-degree polynomial, but it still isn't a good outcome. It’s evident that as we increase the polynomial degree, we experience significant overfitting. This is because while the training set shows a high R2 value, the test set has a very poor R2 score.
